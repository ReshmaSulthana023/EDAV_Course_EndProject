# %% [markdown]
#                                      Chaitanya Bharati Institute of Technology(CBIT),Hyderabad.
#                                               Department of IT,EDAV
# TITLE:
# CBIT/IT-1/EDAV/2025/CEP-17 Roll No:1601-24-737-021, Reshma Sulthana, Analyze disease incidence rates across states and years for key diseases.
#
# OVERVIEW:
# This analysis examines the incidence rates of major diseases such as malaria,Dengue,and measles,etc...across different states over multiple years.By normalizing incidence per 100k population comparisions across the states with different population sizes are made meaningful.
#
# DataSet link: [Link](https://drive.google.com/file/d/1vMh06UEXS6Ih0mBYogCBznFARUoz4wrE/view?usp=sharing)
#
# ENVIRONMENT:
# python --version: Python 3.13.5
#          Libraries Used:numpy,pandas

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Admin\\Downloads\\disease_incidence_modifiable_dataset.csv")
print("Inforamtion of dataset:")
df.info()
# Out:
# Inforamtion of dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2880 entries, 0 to 2879
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               2880 non-null   object
#  1   region              2880 non-null   object
#  2   disease             2880 non-null   object
#  3   year                2880 non-null   int64
#  4   cases               2880 non-null   int64
#  5   incidence_per_100k  2732 non-null   float64
#  6   population          2880 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 157.6+ KB

# %%
print("First 5 rows:")
df.head()
# Out:
# First 5 rows:
#             state region       disease  year  cases  incidence_per_100k  \
# 0  Andhra Pradesh  South  Tuberculosis  2015  48926               42.16
# 1  Andhra Pradesh  South       Malaria  2015  69352                 NaN
# 2  Andhra Pradesh  South        Dengue  2015  65130               56.12
# 3  Andhra Pradesh  South      HIV/AIDS  2015  97021               83.60
# 4  Andhra Pradesh  South       Measles  2015  79569               68.57
#
#    population
# 0   116048524
# 1   116048524
# 2   116048524
# 3   116048524
# 4   116048524

# %% [markdown]
# Q1: Calculate disease incidence mean (BL-3)

# %%
mean_incidence=df["incidence_per_100k"].mean()
print("Disease incidence mean:\n",mean_incidence)
# Out:
# Disease incidence mean:
#  251.05704245973644

# %% [markdown]
# Q2: Filter data for specific diseases (BL-3)

# %%
Filtered_data=df[df['disease'].isin(["Malaria","Dengue","Measles"])]
print("Filtered data of dengue,malaria,measles:\n",Filtered_data)
# Out:
# Filtered data of dengue,malaria,measles:
#                 state region  disease  year  cases  incidence_per_100k  \
# 1     Andhra Pradesh  South  Malaria  2015  69352                 NaN
# 2     Andhra Pradesh  South   Dengue  2015  65130               56.12
# 4     Andhra Pradesh  South  Measles  2015  79569               68.57
# 9     Andhra Pradesh  South  Malaria  2016  46764               92.30
# 10    Andhra Pradesh  South   Dengue  2016   2932                5.79
# ...              ...    ...      ...   ...    ...                 ...
# 2866      Puducherry  South   Dengue  2023  22119              141.72
# 2868      Puducherry  South  Measles  2023  50769                 NaN
# 2873      Puducherry  South  Malaria  2024  49073               42.02
# 2874      Puducherry  South   Dengue  2024  33783               28.93
# 2876      Puducherry  South  Measles  2024  51392               44.00
#
#       population
# 1      116048524
# 2      116048524
# 4      116048524
# ...

# %% [markdown]
# Q3: Impute missing incidence data (BL-4)

# %%
print("empty incidence before imputing:")
print(df["incidence_per_100k"])

print("\nFilled incidence after imputing:\n")
print(df["incidence_per_100k"].fillna(mean_incidence))
# Out:
# empty incidence before imputing:
# 0       42.16
# 1         NaN
# 2       56.12
# 3       83.60
# 4       68.57
#         ...
# 2875    53.21
# 2876    44.00
# 2877    37.39
# 2878    56.05
# 2879    45.36
# Name: incidence_per_100k, Length: 2880, dtype: float64
#
# Filled incidence after imputing:
#
# 0        42.160000
# 1       251.057042
# 2        56.120000
# 3        83.600000
# 4        68.570000
#            ...
# 2875     53.210000
# 2876     44.000000
# 2877     37.390000
# 2878     56.050000
# 2879     45.360000
# Name: incidence_per_100k, Length: 2880, dtype: float64

# %% [markdown]
# Q4: Group and summarize by disease and state (BL-4)

# %%
grouped_data=df.groupby(["disease","state"])

summarizing=grouped_data["incidence_per_100k"].agg(
    count='count',
    mean='mean',
    median='median',
    sum='sum',
    max='max',
    min='min').reset_index()
print("\n\nSummary of the data from incidence_per_100k column:\n",summarizing)

print("\n\nGrouped data by disease and states:\n")
for name,group in grouped_data:
    print("Group",name)
    print(group.head(5))
    print("-"*40)
# Out:
# Summary of the data from incidence_per_100k column:
#            disease                        state  count        mean   median  \
# 0          Dengue  Andaman and Nicobar Islands     10  395.757704  174.190
# 1          Dengue               Andhra Pradesh     10   85.216000   56.450
# 2          Dengue            Arunachal Pradesh     10  131.358000   82.560
# 3          Dengue                        Assam     10   79.766704   70.950
# 4          Dengue                        Bihar     10   90.927704   78.040
# ..            ...                          ...    ...         ...      ...
# 283  Tuberculosis                    Telangana     10  258.922000   91.390
# 284  Tuberculosis                      Tripura     10  129.527704   80.660
# 285  Tuberculosis                Uttar Pradesh     10  248.637000  121.980
# 286  Tuberculosis                  Uttarakhand     10   68.322000   48.450
# 287  Tuberculosis                  West Bengal     10  129.186704   83.875
#
# ...
